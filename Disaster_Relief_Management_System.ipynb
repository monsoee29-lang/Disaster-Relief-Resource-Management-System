# %% [markdown]
# <a href="https://colab.research.google.com/github/monsoee29-lang/Disaster-Relief-Resource-Management-System/blob/main/Disaster_Relief_Management_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Disaster Relief Resource Management System**
#
# Our goal is to build a program to manage donated resources and distribute them based on urgency and location using below data structures:
#
# (1) Linked List for tracking donations
#
# (2) Priority Queue (from Queue) for relief area prioritization
#
# (3) Dijkstra Algorithm for finding the shortest path from a store house (starting point) to a disaster location

# %% [markdown]
# After the catastrophic 7.7 magnitude earthquake in Myanmar on March 28, 2025, citizens, NGOs, and volunteers responded with immense generosity. But without coordination, even the best intentions can lead to chaos. This project simulates a structured resource distribution system using core data structures to optimize disaster relief delivery.

# %% [markdown]
# **Main Functionalities**
#
# 1.   Add donation            (Singly Linked List)
# 2.   Remove donation         (Singly Linked List)
# 3.   Report Disaster         (Priority Queue)
# 4.   Distribute Supplies     (Priority Queue + Singly Linked List)
# 5.   View Supplies           (Singly Linked List)
# 6.   Dijkstra's Algorithm (Shortest Path Algorithm)

# %% [markdown]
# **(1) Add donation (2) Remove donation (5) View Supplies (With Error Handling)**

# %%
class DonationNode:
    def __init__(self, name, location, item, amount, urgency):
        self.name = name #Donor's name
        self.location = location #Donation Location
        self.item = item #Items to donate
        self.amount = amount #Amount of items
        self.urgency = urgency #Urgency level (1=highest, 5=lowest)
        self.next = None


class DonationList:
    def __init__(self):
        self.head = None #Start with an empty donation list

    def append(self, name, location, item, amount, urgency):
        #Error handling for invalid inputs
        if name == "" or location == "" or item == "": #If name, location and item are empty,
            print("Name, location, and item should not be empty.") #It will print this
            return
        try:
            amount = int(amount) #Convert amount to integer if accidently fill as words
            urgency = int(urgency) #Convert urgency to integer
        except ValueError:
            print("Amount and urgency are supposed to be numbers.")
            return

        if amount <= 0: #Amount must be 0 or larger than zero
            print("Amount must be greater than 0.")
            return
        if urgency < 1 or urgency > 5: #Urgency must be between 1 and 5
            print("Urgency must be between 1 and 5.")
            return

        new_node = DonationNode(name, location, item, amount, urgency)

        if self.head is None: #If list is empty,
            self.head = new_node #Create new node
            print(f"Added {name} at {location}: {amount} x {item} (Urgency: {urgency})")
            return

        last = self.head #Start at the head
        while last.next: #Traverse to last node
            last = last.next
        last.next = new_node #Add new node at the end
        print(f"Added {name} at {location}: {amount} x {item} (Urgency: {urgency})")

    #delete by name
    def delete(self, name):
        if not self.head:
            print("The list is empty.")
            return

        current = self.head  #Start from the head
        prev = None

        if current.name.lower() == name.lower(): #If current head is the node to delete
            self.head = current.next #Move head to next node
            print(f"Deleted '{name}' from the list.")
            return

        while current: #Loop through the list till the end
            if current.name.lower() == name.lower():
                prev.next = current.next #Skip over the current node by linking the previous node to the next one
                print(f"Deleted '{name}' from the list.")
                return
            prev = current #Move previous forward to current node
            current = current.next #Move current forward to next node

        print("Item not found.")

    def print_list(self):
        current = self.head
        if not current:
            print("No supplies available.")
            return

        print("\n Current Donations:")
        while current:
            print(f"- {current.name} | {current.amount}x {current.item} | Urgency: {current.urgency} | Location: {current.location}")
            current = current.next

# %%
#Test cases for function1,2,5 (Add donations, Delete donation, View Supplies)
donation_list = DonationList()

donation_list.append("UNICEF", "Yangon", "Water Bottles", 5000, 2)
donation_list.append("Red Cross", "Mandalay", "Medical Supplies", 10000, 1)
donation_list.append("Local Group", "Naypyidaw", "Blankets", 1000, 3)

donation_list.print_list()

donation_list.delete("Red Cross")

#Print list again after deletion
donation_list.print_list()

#Test invalid entries
donation_list.append("", "Yangon", "Food", 30, 2) #Missing name
donation_list.append("Volunteer", "", "Clothing", 20, 2) #Missing location
donation_list.append("Helper", "Sagaing", "Shelter", "ten", 3) #Invalid amount
donation_list.append("NGO", "Magway", "First Aids Kits", 100, 6) #Urgency out of range
# Out:
# Added UNICEF at Yangon: 5000 x Water Bottles (Urgency: 2)
# Added Red Cross at Mandalay: 10000 x Medical Supplies (Urgency: 1)
# Added Local Group at Naypyidaw: 1000 x Blankets (Urgency: 3)
#
#  Current Donations:
# - UNICEF | 5000x Water Bottles | Urgency: 2 | Location: Yangon
# - Red Cross | 10000x Medical Supplies | Urgency: 1 | Location: Mandalay
# - Local Group | 1000x Blankets | Urgency: 3 | Location: Naypyidaw
# Deleted 'Red Cross' from the list.
#
#  Current Donations:
# - UNICEF | 5000x Water Bottles | Urgency: 2 | Location: Yangon
# - Local Group | 1000x Blankets | Urgency: 3 | Location: Naypyidaw
# Name, location, and item should not be empty.
# Name, location, and item should not be empty.
# Amount and urgency are supposed to be numbers.
# Urgency must be between 1 and 5.

# %% [markdown]
# **(3) Disaster Reporting Using PriorityQueue**

# %%
from queue import PriorityQueue #Take a reference from in-class practice

class AidRequestQueue:
    def __init__(self): #Initializes the class
        self.queue = PriorityQueue() #Create priority queue to store

    def report_request(self, location, urgency):
        try:
            urgency = int(urgency) #Urgency is converted to an integer because the request was stored as tuple (location, urgency)
            if urgency < 1 or urgency > 5:
                print("Urgency must be between 1 (frist priority) and 5 (fifth priority).")
                return

            self.queue.put((urgency, location))
            print(f"Reported aid request at {location} with urgency {urgency}.")
        except ValueError:
            print("Urgency must be a number.")

    def get_next_request(self): #get the next most urgent aid request
        if self.queue.empty():
            print("No disasters reported.")
            return None
        return self.queue.get()

    def is_empty(self):
        return self.queue.empty()


#Test Case
aid_queue = AidRequestQueue()

#Report valid requests
aid_queue.report_request("Yangon", 2)
aid_queue.report_request("Mandalay", 1)
aid_queue.report_request("Naypyidaw", 3)

#Report invalid urgency
aid_queue.report_request("Bago", 0)
aid_queue.report_request("Myitkyina", 6)

#Report non-numeric urgency
aid_queue.report_request("Taunggyi", "urgent")

#Retrieve aid requests in priority order
print("\nGetting aid requests by urgency:")
while not aid_queue.is_empty():
    urgency, location = aid_queue.get_next_request()
    print(f"Dispatching aid to {location} (Urgency: {urgency})")

#Try retrieving from an empty queue
aid_queue.get_next_request()
# Out:
# Reported aid request at Yangon with urgency 2.
# Reported aid request at Mandalay with urgency 1.
# Reported aid request at Naypyidaw with urgency 3.
# Urgency must be between 1 (frist priority) and 5 (fifth priority).
# Urgency must be between 1 (frist priority) and 5 (fifth priority).
# Urgency must be a number.
#
# Getting aid requests by urgency:
# Dispatching aid to Mandalay (Urgency: 1)
# Dispatching aid to Yangon (Urgency: 2)
# Dispatching aid to Naypyidaw (Urgency: 3)
# No disasters reported.

# %% [markdown]
# (4) **Distribute Supplies**

# %%
#Match available donations with urgent aid requests (to implement the most urgent request first, and then distributes supplies)
def distribute_supplies(donations, aid_requests): #two things to ask (donations and aid_request)
    if aid_requests.is_empty():
        print("No aid requests to proceed.")
        return

    if donations.head is None: #If donation list is empty, its head is none.
        print("No donations available.") #So, no donations is available.
        return
    #If donation is available, retrieve next most urgent aid request
    request = aid_requests.get_next_request() #request aid based on priority
    urgency = request[0] #access first element at index 0 - Inside the AidRequestQueue class, requests are added using: self.queue.put((urgency, location))
    location = request[1] #access second element at index 1
    print(f"\nDistributing supplies to: {location} (Urgency: {urgency})")

    current = donations.head #Now, take first available donation
    if current: #If current is not none,
        print(f"Sending {current.amount} items from {current.name} to {location}.") #Print supplies with (current.amount) taken from donor's name to requested location
        donations.head = current.next #Move head to next donation
    else:
        print("No donations available to send.")

#Test Case
donations = DonationList()
donations.append("PARAMI", "Sagaing", "Mosquito Net", 500, 3)

aid_requests = AidRequestQueue()
aid_requests.report_request("Sagaing", 1)


distribute_supplies(donations, aid_requests)
distribute_supplies(donations, aid_requests)
# Out:
# Added PARAMI at Sagaing: 500 x Mosquito Net (Urgency: 3)
# Reported aid request at Sagaing with urgency 1.
#
# Distributing supplies to: Sagaing (Urgency: 1)
# Sending 500 items from PARAMI to Sagaing.
# No aid requests to proceed.

# %% [markdown]
# **(6) Dijkstra's Algorithm (Shortest Path Algorithm)**

# %%
def dijkstra(graph, start):
#Nodes=locations (cities, disaster sites)
#Edges=paths with weights
    distances = {node: float('inf') for node in graph} #First, all distance are infinity as they are unknown.
    distances[start] = 0 #Starting point has zero distance.
    visited = set() #To list visited nodes like this {Sagaing, Mandalay, Naypyidaw, Yangon}

    while len(visited) < len(graph): #loop all nodes to be visited
        min_node = None
        min_distance = float('inf')
        #Find shortest distance
        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_node = node #If there is a minimum node,
                min_distance = distances[node] #Shortest distance is found

        if min_node is None: #no more reachable nodes
            break

        visited.add(min_node) #Will add to visited list
#Check and update distances for neighboring nodes
        for neighbor, weight in graph[min_node]:
            if neighbor not in visited: #If neighbor not visited
                new_distance = distances[min_node] + weight #Total distance through current node
                if new_distance < distances[neighbor]:
                    distances[neighbor] = new_distance  #Update if shorter path is found

    return distances

#Test Case
graph = {
    "Yangon": [("Bago", 2), ("Pathein", 5)],
    "Bago": [("Naypyidaw", 4)],
    "Pathein": [("Naypyidaw", 6)],
    "Naypyidaw": [("Mandalay", 3)],
    "Mandalay": [("Sagaing", 2)],
    "Sagaing": []
}
start_location = "Yangon"
result = dijkstra(graph, start_location)

print(f"Shortest distances from {start_location}:")
for location, distance in result.items():
    print(f"{location}: {distance}")
# Out:
# Shortest distances from Yangon:
# Yangon: 0
# Bago: 2
# Pathein: 5
# Naypyidaw: 6
# Mandalay: 9
# Sagaing: 11

# %% [markdown]
# Interactive Menu

# %%
def menu():
   #Initializing empty list and queue
    donations = DonationList()
    aid_requests = AidRequestQueue()

#Graph to show locatons and distance
    graph = {
        "Yangon": [("Bago", 2), ("Pathein", 5)],
        "Bago": [("Naypyidaw", 4)],
        "Pathein": [("Naypyidaw", 6)],
        "Naypyidaw": [("Mandalay", 3)],
        "Mandalay": [("Sagaing", 2)],
        "Sagaing": []
    }
#Traverse to keep the program running until the user chooses to exit
    while True:
        print("\n  Project Pathfinders 7.7")
        print("1. Donate Supplies")
        print("2. Report Disaster")
        print("3. Distribute Supplies")
        print("4. View All Donations")
        print("5. Shortest Paths")
        print("6. Exit")
        choice = input("Choose an option (1-6): ") #Asking to add input

        if choice == '1': #Choice 1 is to add a donation to Linked List
            name = input("Donor name: ")
            location = input("Destination location (where items will be sent): ")
            item = input("Item: ")
            amount = input("Amount: ")
            urgency = input("Urgency (1-5): ")
            donations.append(name, location, item, amount, urgency)

        elif choice == '2': #Choice 2 is to add a disaster aid request to the priority queue
            location = input("Disaster location: ")
            urgency = input("Urgency (1-5): ")
            aid_requests.report_request(location, urgency)

        elif choice == '3': #Distribute all current donations
            distribute_supplies(donations, aid_requests)

        elif choice == '4': #Print all current locations
            donations.print_list()

        elif choice == '5': #Choice 5 is to find and print the shorest paths from a selected starting location
            start = input("Enter starting location for shortest path: ")
            if start not in graph:
                print("Invalid location.")
            else:
                distances = dijkstra(graph, start) #Call dijkstra algorithms, and pass graph and start
                print(f"\nShortest paths from {start}:") #Will print shortest path
                for location, distance in distances.items(): #This will loop through each location and its shortest distance
                    dist_text = distance if distance != float('inf') else 'Not Reachable'
                    print(f"- {location}: {dist_text}")

        elif choice == '6': #Exit the program
            print("Exit")
            break

        else:
            print("Invalid option")
menu()
# Out:
#   Project Pathfinders 7.7
# 1. Donate Supplies
# 2. Report Disaster
# 3. Distribute Supplies
# 4. View All Donations
# 5. Shortest Paths
# 6. Exit
# Choose an option (1-6): 1
# Donor name: Ei Mon
# Destination location (where items will be sent): Sagaing
# Item: Packs
# Amount: 500
# Urgency (1-5): 5
# Added Ei Mon at Sagaing: 500 x Packs (Urgency: 5)
#
#   Project Pathfinders 7.7
# 1. Donate Supplies
# 2. Report Disaster
# 3. Distribute Supplies
# 4. View All Donations
# 5. Shortest Paths
# 6. Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3968803932.py in <cell line: 0>()
#      60         else:
#      61             print("Invalid option")
# ---> 62 menu()
#
# /tmp/ipython-input-3968803932.py in menu()
#      22         print("5. Shortest Paths")
#      23         print("6. Exit")
# ---> 24         choice = input("Choose an option (1-6): ") #Asking to add input
#      25
#      26         if choice == '1': #Choice 1 is to add a donation to Linked List
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# Time Complexity

# %%
def add_n_donations(n):
    dl = DonationList() #Empty list
    for i in range(n): #Applying for loop repeating n times
        dl.append(f"Donor{i}", "City", f"Item{i}", 1, 3)
    return dl

# %%
import time
n = 50 #Number of donations
start = time.time()
donations = add_n_donations(n) #O(n)
end = time.time()
print(f"Time to append {n} donations: {end - start:.4f} seconds")
# Out:
# Added Donor0 at City: 1 x Item0 (Urgency: 3)
# Added Donor1 at City: 1 x Item1 (Urgency: 3)
# Added Donor2 at City: 1 x Item2 (Urgency: 3)
# Added Donor3 at City: 1 x Item3 (Urgency: 3)
# Added Donor4 at City: 1 x Item4 (Urgency: 3)
# Added Donor5 at City: 1 x Item5 (Urgency: 3)
# Added Donor6 at City: 1 x Item6 (Urgency: 3)
# Added Donor7 at City: 1 x Item7 (Urgency: 3)
# Added Donor8 at City: 1 x Item8 (Urgency: 3)
# Added Donor9 at City: 1 x Item9 (Urgency: 3)
# Added Donor10 at City: 1 x Item10 (Urgency: 3)
# Added Donor11 at City: 1 x Item11 (Urgency: 3)
# Added Donor12 at City: 1 x Item12 (Urgency: 3)
# Added Donor13 at City: 1 x Item13 (Urgency: 3)
# Added Donor14 at City: 1 x Item14 (Urgency: 3)
# Added Donor15 at City: 1 x Item15 (Urgency: 3)
# Added Donor16 at City: 1 x Item16 (Urgency: 3)
# Added Donor17 at City: 1 x Item17 (Urgency: 3)
# Added Donor18 at City: 1 x Item18 (Urgency: 3)
# Added Donor19 at City: 1 x Item19 (Urgency: 3)
# Added Donor20 at City: 1 x Item20 (Urgency: 3)
# Added Donor21 at City: 1 x Item21 (Urgency: 3)
# Added Donor22 at City: 1 x Item22 (Urgency: 3)
# Added Donor23 at City: 1 x Item23 (Urgency: 3)
# Added Donor24 at City: 1 x Item24 (Urgency: 3)
# Added Donor25 at City: 1 x Item25 (Urgency: 3)
# Added Donor26 at City: 1 x Item26 (Urgency: 3)
# Added Donor27 at City: 1 x Item27 (Urgency: 3)
# Added Donor28 at City: 1 x Item28 (Urgency: 3)
# Added Donor29 at City: 1 x Item29 (Urgency: 3)
# Added Donor30 at City: 1 x Item30 (Urgency: 3)
# Added Donor31 at City: 1 x Item31 (Urgency: 3)
# Added Donor32 at City: 1 x Item32 (Urgency: 3)
# Added Donor33 at City: 1 x Item33 (Urgency: 3)
# Added Donor34 at City: 1 x Item34 (Urgency: 3)
# Added Donor35 at City: 1 x Item35 (Urgency: 3)
# Added Donor36 at City: 1 x Item36 (Urgency: 3)
# Added Donor37 at City: 1 x Item37 (Urgency: 3)
# Added Donor38 at City: 1 x Item38 (Urgency: 3)
# Added Donor39 at City: 1 x Item39 (Urgency: 3)
# Added Donor40 at City: 1 x Item40 (Urgency: 3)
# Added Donor41 at City: 1 x Item41 (Urgency: 3)
# Added Donor42 at City: 1 x Item42 (Urgency: 3)
# Added Donor43 at City: 1 x Item43 (Urgency: 3)
# Added Donor44 at City: 1 x Item44 (Urgency: 3)
# Added Donor45 at City: 1 x Item45 (Urgency: 3)
# Added Donor46 at City: 1 x Item46 (Urgency: 3)
# Added Donor47 at City: 1 x Item47 (Urgency: 3)
# Added Donor48 at City: 1 x Item48 (Urgency: 3)
# Added Donor49 at City: 1 x Item49 (Urgency: 3)
# Time to append 50 donations: 0.0003 seconds

# %%
donations.delete("Donor0") #Deleting Head node
donations.delete(f"Donor{n-1}") #Deleting last node, O(n)
end = time.time()
print(f"Time to delete 2 nodes: {end - start:.4f} seconds")
# Out:
# Deleted 'Donor0' from the list.
# Deleted 'Donor49' from the list.
# Time to delete 2 nodes: 3.2041 seconds

# %%
donations.print_list() #printing all existing nodes in the linked list
end = time.time()
print(f"Time to print list: {end - start:.4f} seconds")
# Out:
#  Current Donations:
# - Donor1 | 1x Item1 | Urgency: 3 | Location: City
# - Donor2 | 1x Item2 | Urgency: 3 | Location: City
# - Donor3 | 1x Item3 | Urgency: 3 | Location: City
# - Donor4 | 1x Item4 | Urgency: 3 | Location: City
# - Donor5 | 1x Item5 | Urgency: 3 | Location: City
# - Donor6 | 1x Item6 | Urgency: 3 | Location: City
# - Donor7 | 1x Item7 | Urgency: 3 | Location: City
# - Donor8 | 1x Item8 | Urgency: 3 | Location: City
# - Donor9 | 1x Item9 | Urgency: 3 | Location: City
# - Donor10 | 1x Item10 | Urgency: 3 | Location: City
# - Donor11 | 1x Item11 | Urgency: 3 | Location: City
# - Donor12 | 1x Item12 | Urgency: 3 | Location: City
# - Donor13 | 1x Item13 | Urgency: 3 | Location: City
# - Donor14 | 1x Item14 | Urgency: 3 | Location: City
# - Donor15 | 1x Item15 | Urgency: 3 | Location: City
# - Donor16 | 1x Item16 | Urgency: 3 | Location: City
# - Donor17 | 1x Item17 | Urgency: 3 | Location: City
# - Donor18 | 1x Item18 | Urgency: 3 | Location: City
# - Donor19 | 1x Item19 | Urgency: 3 | Location: City
# - Donor20 | 1x Item20 | Urgency: 3 | Location: City
# - Donor21 | 1x Item21 | Urgency: 3 | Location: City
# - Donor22 | 1x Item22 | Urgency: 3 | Location: City
# - Donor23 | 1x Item23 | Urgency: 3 | Location: City
# - Donor24 | 1x Item24 | Urgency: 3 | Location: City
# - Donor25 | 1x Item25 | Urgency: 3 | Location: City
# - Donor26 | 1x Item26 | Urgency: 3 | Location: City
# - Donor27 | 1x Item27 | Urgency: 3 | Location: City
# - Donor28 | 1x Item28 | Urgency: 3 | Location: City
# - Donor29 | 1x Item29 | Urgency: 3 | Location: City
# - Donor30 | 1x Item30 | Urgency: 3 | Location: City
# - Donor31 | 1x Item31 | Urgency: 3 | Location: City
# - Donor32 | 1x Item32 | Urgency: 3 | Location: City
# - Donor33 | 1x Item33 | Urgency: 3 | Location: City
# - Donor34 | 1x Item34 | Urgency: 3 | Location: City
# - Donor35 | 1x Item35 | Urgency: 3 | Location: City
# - Donor36 | 1x Item36 | Urgency: 3 | Location: City
# - Donor37 | 1x Item37 | Urgency: 3 | Location: City
# - Donor38 | 1x Item38 | Urgency: 3 | Location: City
# - Donor39 | 1x Item39 | Urgency: 3 | Location: City
# - Donor40 | 1x Item40 | Urgency: 3 | Location: City
# - Donor41 | 1x Item41 | Urgency: 3 | Location: City
# - Donor42 | 1x Item42 | Urgency: 3 | Location: City
# - Donor43 | 1x Item43 | Urgency: 3 | Location: City
# - Donor44 | 1x Item44 | Urgency: 3 | Location: City
# - Donor45 | 1x Item45 | Urgency: 3 | Location: City
# - Donor46 | 1x Item46 | Urgency: 3 | Location: City
# - Donor47 | 1x Item47 | Urgency: 3 | Location: City
# - Donor48 | 1x Item48 | Urgency: 3 | Location: City
# Time to print list: 243.9675 seconds

# %%
def requests(n):
    aid_queue = AidRequestQueue() #Empty aid request priority queue
    for i in range(n):
        aid_queue.report_request(f"Location{i}", (i % 5) + 1) #Using % operator for generator urgency level so that we can avoid adding manually
    return aid_queue

# %%
n = 50 #number of requests
start = time.time()
aid_queue = requests(n) #O(n log n) > n * O(log n)
end = time.time()
print(f"\nTime to report {n} aid requests: {end - start:.4f} seconds")
# Out:
# Reported aid request at Location0 with urgency 1.
# Reported aid request at Location1 with urgency 2.
# Reported aid request at Location2 with urgency 3.
# Reported aid request at Location3 with urgency 4.
# Reported aid request at Location4 with urgency 5.
# Reported aid request at Location5 with urgency 1.
# Reported aid request at Location6 with urgency 2.
# Reported aid request at Location7 with urgency 3.
# Reported aid request at Location8 with urgency 4.
# Reported aid request at Location9 with urgency 5.
# Reported aid request at Location10 with urgency 1.
# Reported aid request at Location11 with urgency 2.
# Reported aid request at Location12 with urgency 3.
# Reported aid request at Location13 with urgency 4.
# Reported aid request at Location14 with urgency 5.
# Reported aid request at Location15 with urgency 1.
# Reported aid request at Location16 with urgency 2.
# Reported aid request at Location17 with urgency 3.
# Reported aid request at Location18 with urgency 4.
# Reported aid request at Location19 with urgency 5.
# Reported aid request at Location20 with urgency 1.
# Reported aid request at Location21 with urgency 2.
# Reported aid request at Location22 with urgency 3.
# Reported aid request at Location23 with urgency 4.
# Reported aid request at Location24 with urgency 5.
# Reported aid request at Location25 with urgency 1.
# Reported aid request at Location26 with urgency 2.
# Reported aid request at Location27 with urgency 3.
# Reported aid request at Location28 with urgency 4.
# Reported aid request at Location29 with urgency 5.
# Reported aid request at Location30 with urgency 1.
# Reported aid request at Location31 with urgency 2.
# Reported aid request at Location32 with urgency 3.
# Reported aid request at Location33 with urgency 4.
# Reported aid request at Location34 with urgency 5.
# Reported aid request at Location35 with urgency 1.
# Reported aid request at Location36 with urgency 2.
# Reported aid request at Location37 with urgency 3.
# Reported aid request at Location38 with urgency 4.
# Reported aid request at Location39 with urgency 5.
# Reported aid request at Location40 with urgency 1.
# Reported aid request at Location41 with urgency 2.
# Reported aid request at Location42 with urgency 3.
# Reported aid request at Location43 with urgency 4.
# Reported aid request at Location44 with urgency 5.
# Reported aid request at Location45 with urgency 1.
# Reported aid request at Location46 with urgency 2.
# Reported aid request at Location47 with urgency 3.
# Reported aid request at Location48 with urgency 4.
# Reported aid request at Location49 with urgency 5.
#
# Time to report 50 aid requests: 0.0009 seconds

# %%
start = time.time()
count = 0 #starting a counter
while not aid_queue.is_empty():
    aid_queue.get_next_request() #O(n log n) > n * O(log n)
    count += 1 #process the request count
end = time.time()
print(f"Time to process {count} aid requests (get_next_request): {end - start:.4f} seconds")
# Out:
# Time to process 0 aid requests (get_next_request): 0.0001 seconds

# %%
def measure_dijkstra_time(graph, start):
    start_time = time.time()
    distances = dijkstra(graph, start) #O(n²)
    end_time = time.time()
    print(f"Time to run Dijkstra's algorithm: {end_time - start_time:.6f} seconds")
    return distances
distances = measure_dijkstra_time(graph, start_location)
# Out:
# Time to run Dijkstra's algorithm: 0.000023 seconds
